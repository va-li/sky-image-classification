# %%
# Uncomment the needed imports (VSCode: Ctrl+Shift+7)

### data manipulation support ###

import numpy as np
import pandas as pd

### data visualization and interactivity support ###

import holoviews as hv
import hvplot.pandas
hv.extension('bokeh')

from matplotlib import pyplot as plt

from skimage import io

# import panel as pn
# pn.extension()

# import geopandas as gpd
# import geoviews as gv
# gv.extension('bokeh')

### data science support ###

# import scipy
# import sklearn
# import statsmodels.api as sm

### programming and typing support ###

from typing import Dict, List, Tuple, Union, Optional, Any, Callable, Iterable, Literal
from pathlib import Path
from dataclasses import dataclass
from joblib import Parallel, delayed
import warnings
from tqdm import tqdm
import zipfile

### pytorch ###
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import DataLoader, Dataset
import torchvision

# %load_ext watermark
# %watermark -u -i -v -iv -m -co -a 'Valentin Bauer'
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# ...

# %%
model = torchvision.models.mobilenet_v3_large(weights=None)
model.classifier = nn.Sequential(
  nn.Linear(in_features=960, out_features=1280, bias=True),
  nn.Hardswish(),
  nn.Dropout(p=0.2, inplace=True),
  nn.Linear(in_features=1280, out_features=5, bias=True),
  nn.Sigmoid()
)

# best_model_weights = torch.load('/home/vbauer/MEGA/Master/Data Science/2024 WS/Applied Deep Learning/sky-image-classification/data/training-runs/mobilenetv3_20241116-135542+0100/best_model.pth')
best_model_weights = torch.load('/home/vbauer/MEGA/Master/Data Science/2024 WS/Applied Deep Learning/sky-image-classification/data/training-runs/mobilenetv3_20241118-143341+0100/best_model.pth')
model.load_state_dict(best_model_weights)
# model.classifier[0].weight = nn.Parameter(best_model_weights['classifier.3.0.weight'])
# model.classifier[0].bias = nn.Parameter(best_model_weights['classifier.3.0.bias'])
# model.classifier[3].weight = nn.Parameter(best_model_weights['classifier.3.2.weight'])
# model.classifier[3].bias = nn.Parameter(best_model_weights['classifier.3.2.bias'])
# Out:
# <All keys matched successfully>

# %%
model.classifier
# Out:
# Sequential(
#   (0): Linear(in_features=960, out_features=1280, bias=True)
#   (1): Hardswish()
#   (2): Dropout(p=0.2, inplace=True)
#   (3): Linear(in_features=1280, out_features=5, bias=True)
#   (4): Sigmoid()
# )

# %%
list(model.classifier.state_dict().keys())
# Out:
# ['0.weight', '0.bias', '3.weight', '3.bias']

# %%
mobilenet = torchvision.models.mobilenet_v3_large(weights=None)
list(mobilenet.classifier.state_dict().keys())
# Out:
# ['0.weight', '0.bias', '3.weight', '3.bias']

# %%
mobilenet.classifier
# Out:
# Sequential(
#   (0): Linear(in_features=960, out_features=1280, bias=True)
#   (1): Hardswish()
#   (2): Dropout(p=0.2, inplace=True)
#   (3): Linear(in_features=1280, out_features=1000, bias=True)
# )

# %%
list(mobilenet.classifier.state_dict().keys())
# Out:
# ['0.weight', '0.bias', '3.weight', '3.bias']

# %%
list(model.state_dict().keys())
# Out:
# ['features.0.0.weight',
#  'features.0.1.weight',
#  'features.0.1.bias',
#  'features.0.1.running_mean',
#  'features.0.1.running_var',
#  'features.0.1.num_batches_tracked',
#  'features.1.block.0.0.weight',
#  'features.1.block.0.1.weight',
#  'features.1.block.0.1.bias',
#  'features.1.block.0.1.running_mean',
#  'features.1.block.0.1.running_var',
#  'features.1.block.0.1.num_batches_tracked',
#  'features.1.block.1.0.weight',
#  'features.1.block.1.1.weight',
#  'features.1.block.1.1.bias',
#  'features.1.block.1.1.running_mean',
#  'features.1.block.1.1.running_var',
#  'features.1.block.1.1.num_batches_tracked',
#  'features.2.block.0.0.weight',
#  'features.2.block.0.1.weight',
#  'features.2.block.0.1.bias',
#  'features.2.block.0.1.running_mean',
#  'features.2.block.0.1.running_var',
#  'features.2.block.0.1.num_batches_tracked',
#  'features.2.block.1.0.weight',
#  'features.2.block.1.1.weight',
#  'features.2.block.1.1.bias',
#  'features.2.block.1.1.running_mean',
# ...

# %%
def predict_image_label_scores(model: nn.Module, transform, image_path: str | Path) -> np.ndarray:
    model.eval()
    model.to('cpu')
    image = io.imread(image_path)
    
    image = transform(image)
    with torch.no_grad():
        prediction = model(image.unsqueeze(0)).squeeze()
    return prediction.numpy()
# Out:
# array([9.9997914e-01, 9.8901713e-01, 3.5600620e-03, 1.9782930e-05,
#        7.2235777e-04], dtype=float32)

# %%
# show the image and the predicted_label scores ordered by highest score

def plot_image_and_predicted_label_scores(image_path: Path, label_scores: np.ndarray, label_names: List[str]):
    if len(label_scores) != len(label_names):
        raise ValueError('label_scores and label_names must have the same length')
    fig, ax = plt.subplots()
    image = io.imread(image_path)
    ax.imshow(image)
    ax.axis('off')
    plt.show()
    
    sorted_label_scores = sorted(zip(label_scores, label_names), key=lambda x: x[0], reverse=True)
    for score, label in sorted_label_scores:
        print(f'{label}: {score:.2f}')

# %%
# image_path = Path('/home/vbauer/MEGA/Master/Data Science/2024 WS/Applied Deep Learning/sky-image-classification/data/sky-images/daedalus/daedalus_2024-06-01T09-30-00-006100+00-00.jpg')
# image_path = Path('/home/vbauer/MEGA/Master/Data Science/2024 WS/Applied Deep Learning/sky-image-classification/data/sky-images/daedalus/daedalus_2024-06-26T07-00-00-006205+00-00.jpg')
# image_path = Path('/home/vbauer/MEGA/Master/Data Science/2024 WS/Applied Deep Learning/sky-image-classification/data/sky-images/daedalus/daedalus_2024-08-14T12-00-00-006158+00-00.jpg')
# image_path = Path('/home/vbauer/MEGA/Master/Data Science/2024 WS/Applied Deep Learning/sky-image-classification/data/sky-images/daedalus/daedalus_2024-08-24T09-15-00-006592+00-00.jpg')
image_path = Path('/home/vbauer/MEGA/Master/Data Science/2024 WS/Applied Deep Learning/sky-image-classification/data/sky-images/daedalus/daedalus_2024-09-17T06-00-00-006219+00-00.jpg')
# image_path = Path('/home/vbauer/MEGA/Master/Data Science/2024 WS/Applied Deep Learning/sky-image-classification/data/sky-images/ikarus/ikarus_2024-05-22T15-57-58-017680+00-00.jpg')

transform = torchvision.transforms.Compose([
    torchvision.transforms.ToTensor(),
    # torchvision.transforms.RandomHorizontalFlip(p=1),
    #resize to 224x224 because the model needs this size
    torchvision.transforms.Resize((224, 224), antialias=True),
    torchvision.transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

from dataset import SkyImageMultiLabelDataset
data_dir = Path('/home/vbauer/MEGA/Master/Data Science/2024 WS/Applied Deep Learning/sky-image-classification/data')
ds = SkyImageMultiLabelDataset(data_dir, transform=transform)

predicted_scores = predict_image_label_scores(model, transform, image_path)

plot_image_and_predicted_label_scores(image_path, predicted_scores, ds.label_names)
# Out:
# clouds: 0.96
# rain: 0.85
# dew: 0.50
# soiling: 0.24
# clear sky: 0.03
